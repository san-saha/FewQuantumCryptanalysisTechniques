# %%
n=32       #size of one word
r=20      #rounds

# %%
# state size
print("state size:", 16*n)
# Out:
# state size: 512

# %% [markdown]
# #### addition

# %%
print("Addition:")
q=2*n
ancilla=1
add_cnot=5*n-7
add_toffoli=2*n-3
add_depth=2*n+2
print("qubits\t",q)
print("ancilla\t",add_ancilla)
print("cnot\t",add_cnot)
print("toffoli\t", add_toffoli)
print("depth\t", add_depth)
# Out:
# Addition:
# qubits	 64
# ancilla	 1
# cnot	 153
# toffoli	 61
# depth	 66

# %% [markdown]
# #### rotation

# %%
print("Rotation:")
q=n
rot_cnot=0
rot_toffoli=0
rot_depth=0
print("qubits\t",q)
# Out:
# Rotation:
# qubits	 32

# %% [markdown]
# #### xor

# %%
print("XOR:")
q=2*n
xor_cnot=n
xor_toffoli=0
xor_depth=1
print("qubits\t",q)
print("cnot\t",xor_cnot)
print("depth\t",xor_depth)
# Out:
# XOR:
# qubits	 64
# cnot	 32
# depth	 1

# %% [markdown]
# #### 1 ARX

# %%
print("1 arx")
q=3*n
arx_ancilla=1
arx_cnot=add_cnot + xor_cnot
arx_toffoli=add_toffoli_xor_toffoli
arx_depth=add_depth + xor_depth
